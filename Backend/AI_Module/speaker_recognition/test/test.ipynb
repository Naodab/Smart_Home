# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def visualize_audio_features_with_mfcc(audio_path1, audio_path2, sr=16000, n_mfcc=13):
    # Load hai tệp âm thanh
    y1, _ = librosa.load(audio_path1, sr=sr)
    y2, _ = librosa.load(audio_path2, sr=sr)

    # Tính MFCC
    mfcc1 = librosa.feature.mfcc(y=y1, sr=sr, n_mfcc=n_mfcc, hop_length=512, n_fft=2048)
    mfcc2 = librosa.feature.mfcc(y=y2, sr=sr, n_mfcc=n_mfcc, hop_length=512, n_fft=2048)

    # Vẽ biểu đồ
    plt.figure(figsize=(12, 8))

    # Biểu đồ sóng âm thanh 1
    plt.subplot(2, 2, 1)
    librosa.display.waveshow(y1, sr=sr)
    plt.title("Waveform - Audio 1")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")

    # Biểu đồ MFCC âm thanh 1
    plt.subplot(2, 2, 2)
    librosa.display.specshow(mfcc1, sr=sr, hop_length=512, x_axis='time', cmap='viridis')
    plt.title("MFCC - Audio 1")
    plt.colorbar(format='%+2.0f')

    # Biểu đồ sóng âm thanh 2
    plt.subplot(2, 2, 3)
    librosa.display.waveshow(y2, sr=sr)
    plt.title("Waveform - Audio 2")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")

    # Biểu đồ MFCC âm thanh 2
    plt.subplot(2, 2, 4)
    librosa.display.specshow(mfcc2, sr=sr, hop_length=512, x_axis='time', cmap='viridis')
    plt.title("MFCC - Audio 2")
    plt.colorbar(format='%+2.0f')

    plt.tight_layout()
    plt.show()

# Ví dụ sử dụng
audio_path1 = "../data/Hoang/Hoang_01.wav"
audio_path2 = "../data/Hoang/angry.wav"
visualize_audio_features_with_mfcc(audio_path1, audio_path2)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial.distance import cosine

def visualize_audio_similarity(audio_path1, audio_path2, sr=16000, n_mfcc=13):
  # Load hai tệp âm thanh
  y1, _ = librosa.load(audio_path1, sr=sr)
  y2, _ = librosa.load(audio_path2, sr=sr)

  # Tính MFCC
  mfcc1 = librosa.feature.mfcc(y=y1, sr=sr, n_mfcc=n_mfcc, hop_length=512, n_fft=2048)
  mfcc2 = librosa.feature.mfcc(y=y2, sr=sr, n_mfcc=n_mfcc, hop_length=512, n_fft=2048)

  # Tính khoảng cách cosine giữa các vector MFCC trung bình
  mfcc1_mean = np.mean(mfcc1, axis=1)
  mfcc2_mean = np.mean(mfcc2, axis=1)
  cosine_distance = cosine(mfcc1_mean, mfcc2_mean)

  # Vẽ biểu đồ
  plt.figure(figsize=(14, 10))

  # Biểu đồ sóng âm thanh 1
  plt.subplot(3, 2, 1)
  librosa.display.waveshow(y1, sr=sr)
  plt.title("Waveform - Audio 1")
  plt.xlabel("Time (s)")
  plt.ylabel("Amplitude")

  # Biểu đồ MFCC âm thanh 1
  plt.subplot(3, 2, 2)
  librosa.display.specshow(mfcc1, sr=sr, hop_length=512, x_axis='time', cmap='viridis')
  plt.title("MFCC - Audio 1")
  plt.colorbar(format='%+2.0f')

  # Biểu đồ sóng âm thanh 2
  plt.subplot(3, 2, 3)
  librosa.display.waveshow(y2, sr=sr)
  plt.title("Waveform - Audio 2")
  plt.xlabel("Time (s)")
  plt.ylabel("Amplitude")

  # Biểu đồ MFCC âm thanh 2
  plt.subplot(3, 2, 4)
  librosa.display.specshow(mfcc2, sr=sr, hop_length=512, x_axis='time', cmap='viridis')
  plt.title("MFCC - Audio 2")
  plt.colorbar(format='%+2.0f')

  # Biểu đồ so sánh MFCC trung bình
  plt.subplot(3, 2, 5)
  plt.plot(mfcc1_mean, label="Audio 1", marker='o')
  plt.plot(mfcc2_mean, label="Audio 2", marker='x')
  plt.title("Mean MFCC Comparison")
  plt.xlabel("MFCC Coefficients")
  plt.ylabel("Value")
  plt.legend()

  # Hiển thị khoảng cách cosine
  plt.subplot(3, 2, 6)
  plt.text(0.5, 0.5, f"Cosine Distance: {cosine_distance:.4f}", fontsize=14, ha='center', va='center')
  plt.axis('off')

  plt.tight_layout()
  plt.show()

# Ví dụ sử dụng
audio_path1 = "../datasets/train/Hoang/Hoang_bat_den_nha_bep.wav"  # Âm thanh của người 1
audio_path2 = "../datasets/train/Huy/Huy_bat_den_nha_bep.wav"      # Âm thanh của người 2
visualize_audio_similarity(audio_path1, audio_path2)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial.distance import cosine

def visualize_audio_similarity(audio_path1, audio_path2, sr=16000, n_mfcc=13):
    # Load hai tệp âm thanh
    y1, _ = librosa.load(audio_path1, sr=sr)
    y2, _ = librosa.load(audio_path2, sr=sr)

    # Tính MFCC
    mfcc1 = librosa.feature.mfcc(y=y1, sr=sr, n_mfcc=n_mfcc, hop_length=512, n_fft=2048)
    mfcc2 = librosa.feature.mfcc(y=y2, sr=sr, n_mfcc=n_mfcc, hop_length=512, n_fft=2048)

    # Tính khoảng cách cosine giữa các vector MFCC trung bình
    mfcc1_mean = np.mean(mfcc1, axis=1)
    mfcc2_mean = np.mean(mfcc2, axis=1)
    cosine_distance = cosine(mfcc1_mean, mfcc2_mean)

    # Vẽ biểu đồ
    plt.figure(figsize=(14, 10))

    # Biểu đồ sóng âm thanh 1
    plt.subplot(3, 2, 1)
    librosa.display.waveshow(y1, sr=sr)
    plt.title("Waveform - Audio 1")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")

    # Biểu đồ MFCC âm thanh 1
    plt.subplot(3, 2, 2)
    librosa.display.specshow(mfcc1, sr=sr, hop_length=512, x_axis='time', cmap='viridis')
    plt.title("MFCC - Audio 1")
    plt.colorbar(format='%+2.0f')

    # Biểu đồ sóng âm thanh 2
    plt.subplot(3, 2, 3)
    librosa.display.waveshow(y2, sr=sr)
    plt.title("Waveform - Audio 2")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")

    # Biểu đồ MFCC âm thanh 2
    plt.subplot(3, 2, 4)
    librosa.display.specshow(mfcc2, sr=sr, hop_length=512, x_axis='time', cmap='viridis')
    plt.title("MFCC - Audio 2")
    plt.colorbar(format='%+2.0f')

    # Biểu đồ so sánh MFCC trung bình
    plt.subplot(3, 2, 5)
    plt.plot(mfcc1_mean, label="Audio 1", marker='o')
    plt.plot(mfcc2_mean, label="Audio 2", marker='x')
    plt.title("Mean MFCC Comparison")
    plt.xlabel("MFCC Coefficients")
    plt.ylabel("Value")
    plt.xticks(range(len(mfcc1_mean)))
    plt.legend()

    # Hiển thị khoảng cách cosine
    plt.subplot(3, 2, 6)
    plt.text(0.5, 0.5, f"Cosine Distance: {cosine_distance:.4f}", fontsize=14, ha='center', va='center')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Ví dụ sử dụng
audio_path1 = "../datasets/train/Hoang/Hoang_bat_den_nha_bep.wav"  # Âm thanh của người 1
audio_path2 = "../datasets/train/Hoang/Hoang_tat_quat_phong_ngu.wav"      # Âm thanh của người 2
visualize_audio_similarity(audio_path1, audio_path2)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial.distance import cosine

def visualize_audio_similarity(audio_path1, audio_path2, sr=16000, n_mfcc=13):
    # Load hai tệp âm thanh
    y1, _ = librosa.load(audio_path1, sr=sr)
    y2, _ = librosa.load(audio_path2, sr=sr)

    # Tính MFCC
    mfcc1 = librosa.feature.mfcc(y=y1, sr=sr, n_mfcc=n_mfcc, hop_length=512, n_fft=2048)
    mfcc2 = librosa.feature.mfcc(y=y2, sr=sr, n_mfcc=n_mfcc, hop_length=512, n_fft=2048)

    # Tính khoảng cách cosine giữa các vector MFCC trung bình
    mfcc1_mean = np.mean(mfcc1, axis=1)
    mfcc2_mean = np.mean(mfcc2, axis=1)
    cosine_distance = cosine(mfcc1_mean, mfcc2_mean)

    # Vẽ biểu đồ
    plt.figure(figsize=(14, 10))

    # Biểu đồ sóng âm thanh 1
    plt.subplot(3, 2, 1)
    librosa.display.waveshow(y1, sr=sr)
    plt.title("Waveform - Audio 1")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")

    # Biểu đồ MFCC âm thanh 1
    plt.subplot(3, 2, 2)
    librosa.display.specshow(mfcc1, sr=sr, hop_length=512, x_axis='time', cmap='viridis')
    plt.title("MFCC - Audio 1")
    plt.colorbar(format='%+2.0f')

    # Biểu đồ sóng âm thanh 2
    plt.subplot(3, 2, 3)
    librosa.display.waveshow(y2, sr=sr)
    plt.title("Waveform - Audio 2")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")

    # Biểu đồ MFCC âm thanh 2
    plt.subplot(3, 2, 4)
    librosa.display.specshow(mfcc2, sr=sr, hop_length=512, x_axis='time', cmap='viridis')
    plt.title("MFCC - Audio 2")
    plt.colorbar(format='%+2.0f')

    # Biểu đồ so sánh MFCC trung bình
    plt.subplot(3, 2, 5)
    plt.plot(mfcc1_mean, label="Audio 1", marker='o')
    plt.plot(mfcc2_mean, label="Audio 2", marker='x')
    plt.title("Mean MFCC Comparison")
    plt.xlabel("MFCC Coefficients")
    plt.ylabel("Value")
    plt.xticks(range(len(mfcc1_mean)))
    plt.legend()

    # Hiển thị khoảng cách cosine
    plt.subplot(3, 2, 6)
    plt.text(0.5, 0.5, f"Cosine Distance: {cosine_distance:.4f}", fontsize=14, ha='center', va='center')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Ví dụ sử dụng
audio_path1 = "../datasets/train/Hoang/Hoang_tat_quat_phong_ngu.wav"  # Âm thanh của người 1
audio_path2 = "../datasets/train/Doan/Doan_tat_quat_phong_ngu.wav"      # Âm thanh của người 2
visualize_audio_similarity(audio_path1, audio_path2)
